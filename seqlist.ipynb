# %% [markdown]
# ## EXAMPLE1
#
# ```mermaid
# flowchart LR
# classDef redBold fill:#fff,stroke:red, font-weight:bold,font-style:italic, color: #fff000
# classDef GreenBold fill:#0f0,stroke:black,font-weight:bold,font-style:italic, color:#fff
#     subgraph MF01判斷
#         A1[DB0049]  z1@==>|NOT| C1(((任一訊號為TRUE)))
#         B1[DI0093] z2@==>|NOT| C1
#         D1[DI0001] z3@==>|NOT| C1
#         linkStyle 0,1,2 stroke:red,font-style:italic, font-weight:bold, label-color:red
#
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1 -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#
#         z1@{ animate: true}
#         z2@{ animate: true}
#         z3@{ animate: true}
#
#          class A1,B1,D1 redBold
#          class C1 GreenBold
#     end
#
#     subgraph MF02判斷
#         A2[DI0052] z11@==>|***NOT***| C2
#         B2[DI0050] z12@==>|***NOT***| C2
#         linkStyle 11,12 stroke:red,font-style:italic, font-weight:bold
#
#         G2[IN0154] -->|TRUE| C2
#         H2[IN0165] -->|TRUE| C2
#         I2[IN0166] -->|TRUE| C2
#         C2(((任一訊號為TRUE))) -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#         z11@{ animate: true}
#         z12@{ animate: true}
#         class C2 GreenBold
#
#         class A2,B2 redBold
#     end
#
#     subgraph MF03判斷
#         A3[IN0168] -->|TRUE| C3
#         B3[IN0169] -->|TRUE| C3
#         D3[IN0170] -->|TRUE| C3
#         G3[IN0171] -->|TRUE| C3
#         H3[IN0172] -->|TRUE| C3
#         I3[IN0173] -->|TRUE| C3
#         C3(((任一訊號為TRUE))) -->|TRUE| E3[MF03 = TRUE]
#         C3 -->|FALSE| F3[MF03 維持 FALSE]
#         class C3 GreenBold
#     end
#
#     subgraph MF條件判斷
#         E1 --> C4(((任一MF為TRUE)))
#         E2 --> C4
#         E3 --> C4
#         C4 -->|TRUE| K4[UA0251 = TRUE]
#         C4 -->|FALSE| K5[UA0251 維持 FALSE]
#         class C4 GreenBold
#     end
#
#     subgraph 警報復歸
#         K4 z31@==>|***NOT***| B4[UA0251=0]
#         B4 --> B10[DI0037=TRUE]
#         z31@{ animate: true}
#
#         linkStyle 31 stroke:red,font-style:italic, font-weight:bold
#     end
# ```

# %% [markdown]
# ## 📚 學習路徑狀態圖
#
# ```mermaid
# stateDiagram-v2
#     direction TB  // 方向設定為由左至右 (Left to Right)
#
#     %% 狀態定義 (State Definitions)
#     %% 使用 state 來定義一個複合狀態 (一個大的分類)
#
#     state "🏭 工業自動化" as Automation {
#         DCS: DCS控制系統與Mermaid
#         PLC: PLC 技術 (MELSEC-Q)
#         HMI: HMI 教學 (iFIX)
#
#         DCS --> PLC : 學習路徑
#         PLC --> HMI : 學習路徑
#     }
#
#     state "💻 PROGRAMING" as Programming {
#         GitHub: 版本控制
#         Python: Python with AI/ML
#         Docker: 容器化技術
#
#         GitHub --> Python
#         Python --> Docker
#     }
#
#     state "🔗 區塊鏈技術" as Blockchain {
#         SmartContract: 智能合約應用
#     }
#
#     %% 起點與主要流程
#     [*] --> Home : 開始學習
#
#     Home : 👋 首頁總覽 (README.md)
#     Home --> Automation : 深入研究
#     Home --> Programming : 深入研究
#     Home --> Blockchain : 探索領域
#
#     %% 終點
#     Automation --> Integration
#     Programming --> Integration
#     Blockchain --> Integration
#
#     Integration: 📚 Integration
#     Integration--> [*] : 階段性完成
# ```

# %% [markdown]
# # ====================================================================
# #                      修正後的 mkdocs.yml
# # ====================================================================
#
# # 網站基本資訊
# site_name: Hachi 的跨領域學習筆記
# # site_url: https://hachi.github.io/DCS-learning/
# repo_url: https://github.com/hachi/DCS-learning
# repo_name: hachi/DCS-learning
# site_author: Hachi Tsai
#
# # 主題與外觀設定
# theme:
#   name: material
#   language: zh-TW # 繁體中文
#   features:
#     - navigation.tabs
#     - navigation.top
#     - toc.integrate
#     - content.code.copy
#     - search.suggest
#     - search.highlight
#     - navigation.instant
#     - navigation.tracking
#   palette:
#     # 淺色模式
#     - scheme: default
#       toggle:
#         icon: material/brightness-7
#         name: 切換到深色模式
#     # 深色模式
#     - scheme: slate
#       toggle:
#         icon: material/brightness-4
#         name: 切換到淺色模式
#
# # 導覽列設定
# nav:
#   - 👋 首頁總覽: index.md
#   - 工業自動化:
#       - DCS控制系統與Mermaid:
#           - 邏輯控制圖像化: DCS/Hitachi/Control-logic-mermaid.md
#           - 控制邏輯筆記: DCS/Hitachi/concepts.md
#           - 技術日文筆記: DCS/Hitachi/japanese.md
#       - PLC 技術:
#           - MELSEC-Q 操作筆記: PLC/MELSEC-Q.md
#       - HMI 教學:
#           - iFIX 筆記: HMI/iFIX.md
#   - 區塊鏈技術:
#       - 智能合約應用: BlockChain/SmartContract.md
#   - PROGRAMING:
#       - GitHub: Programing/github.md
#       - Python with AI-ML: Programing/python-with-aiml.md
#       - Docker: Programing/docker.md
#   - 資源整理:
#       - 常用工業通訊協定: Resources/OT-communicating-protocl.md
#       - 推薦學習資源: Resources/Coursera/Learning_Schedule.md
#
# # Markdown 擴充功能
# markdown_extensions:
#   - admonition
#   - md_in_html
#   - footnotes
#   - toc:
#       permalink: true
#   - tables
#   - pymdownx.snippets
#   - pymdownx.emoji
#   - pymdownx.highlight
#   - pymdownx.inlinehilite
#   - pymdownx.tabbed
#   # Mermaid 的關鍵設定
#   - pymdownx.superfences:
#       custom_fences:
#         - name: mermaid
#           class: mermaid
#           format: !!python/name:pymdownx.superfences.fence_code_format
#
# # ↓↓↓↓↓↓ 額外的 CSS 與 JS 設定 ↓↓↓↓↓↓
# # 確保你的檔案路徑是 docs/stylesheets/extra.css
# extra_css:
#   - stylesheets/extra.css
#
# # 社群連結
# extra:
#   social:
#     - icon: fontawesome/brands/github
#       link: https://github.com/hachi
#     - icon: fontawesome/brands/linkedin
#       link: https://linkedin.com/in/hachi-tsai

# %% [markdown]
# ```mermaid
# mindmap  root((Industrial-automation-learning/))
#     README.md
#     工業自動化
#       DCS控制系統與Mermaid/
#         產線控制圖像化
#         控制系統邏輯筆記
#         技術日文筆記
#       PLC/
#         MELSEC-Q
#         Screensho/
#       HMI/
#         iFIX
#         Screenshots/
#     BLOCKCHAIN/
#       Smart-Contract/
#       Tracking-Zone
#     PROGRAMING
#       Github
#       Python with AI-ML/
#       Docker
#     Resources/
#       工控常用通訊協定
#       推薦學習資源
# ```

# %% [markdown]
# # FOR-TEST-SEQ002-E210-沒有將每個模組分開的情況
#
# ```mermaid
# flowchart LR
#     subgraph SEQ001 判斷流程
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1 -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#
#         A2[DI0052] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2{任一訊號為TRUE}
#         B2[DI0050] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2
#         G2[IN0154] -->|TRUE| C2
#         H2[IN0165] -->|TRUE| C2
#         I2[IN0166] -->|TRUE| C2
#         C2 -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#
#         A3[IN0168] -->|TRUE| C3{任一訊號為TRUE}
#         B3[IN0169] -->|TRUE| C3
#         D3[IN0170] -->|TRUE| C3
#         G3[IN0171] -->|TRUE| C3
#         H3[IN0172] -->|TRUE| C3
#         I3[IN0173] -->|TRUE| C3
#         C3 -->|TRUE| E3[MF03 = TRUE]
#         C3 -->|FALSE| F3[MF03 維持 FALSE]
#
#         E1 -->|TRUE| C4{任一MF為TRUE}
#         E2 -->|TRUE| C4
#         E3 -->|TRUE| C4
#         C4 -->|TRUE| K4[K1 = TRUE]
#         C4 -->|FALSE| K5[K1 維持 FALSE]
#     end
# ```

# %% [markdown]
# # SEQ002-E210-每一段都分開
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[DI0052] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2
#         B2[DI0050] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2
#         G2[IN0154] -->|TRUE| C2
#         H2[IN0165] -->|TRUE| C2
#         I2[IN0166] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF03判斷
#         A3[IN0168] -->|TRUE| C3
#         B3[IN0169] -->|TRUE| C3
#         D3[IN0170] -->|TRUE| C3
#         G3[IN0171] -->|TRUE| C3
#         H3[IN0172] -->|TRUE| C3
#         I3[IN0173] -->|TRUE| C3
#         C3{任一訊號為TRUE} -->|TRUE| E3[MF03 = TRUE]
#         C3 -->|FALSE| F3[MF03 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#         E1 --> C4{任一MF為TRUE}
#         E2 --> C4
#         E3 --> C4
#         C4 -->|TRUE| K4[UA0251 = TRUE]
#         C4 -->|FALSE| K5[UA0251 維持 FALSE]
#     end
#
#     subgraph 警報復歸
#         K4 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT UA0251=0</font>"| B4[DO0037=TRUE]
#     end
# ```

# %% [markdown]
# # SEQ003-NV2124
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         M1[IN0109] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[DI0074] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2{任一訊號為TRUE}
#         G2[IN0167] -->|TRUE| C2
#         H2[IN0139] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[VI002 = TRUE]
#     C4 -->|FALSE| K5[VI002 維持 FALSE]
#     end
# ```
# ## ZO0074(A/M mode; 0=A / 1=M)常時為1,若不等於1 則發警報
# ```mermaid
#     flowchart LR
#         A3[IX0001] -->|TRUE| A4[ZO0074=1=M]
#         A4 -->B3[DB0074=0=M] -->|DB0074=0| B4[DI1002=1<br>UA0253=0]
#         B3 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT DB0075=1</font>"| D4[DI1002=0<br>UA0252=1]
# ```

# %% [markdown]
# # SEQ004-NV2123
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         M1[IN0109] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[IN0154] -->|TRUE| C2{任一訊號為TRUE}
#         G2[IX000] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[VI002 = TRUE]
#     C4 -->|FALSE| K5[VI002 維持 FALSE]
#     end
# ```
# ## ZO0075(A/M mode; 0=A / 1=M)常時為1,若不等於1 則發警報
# ```mermaid
#     flowchart LR
#         A3[IX0001] -->|TRUE| A4[ZO0075=1=M]
#         A4 -->B3[DB0075=0=M] -->|DB0075=0| B4[DI1003=1<br>UA0253=0]
#         B3 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT DB0075=1</font>"| D4[DI1003=0<br>UA0253=1]
# ```

# %% [markdown]
# # SEQ005-E180
# ## MF01
# ```mermaid
# flowchart LR
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         M1[IN0109] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
# ```
# ## 連鎖警報
# ```mermaid
# flowchart LR
#         A2[DI0069] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C3[訊號同時為TRUE]
#         G2[IN0302] -->|TRUE| C3
#         C3 -->|TRUE| E3[UA0069 = TRUE]
#         style C3 fill:#fff,stroke:#333,stroke-width:1px,color:#0000ff
#
#         A4[IN0302] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C4[訊號同時為TRUE]
#         G4[IN0125] -->|TRUE| C4
#         C4 -->|TRUE| E4[UA0125 = TRUE]
#         style C4 fill:#fff,stroke:#333,stroke-width:1px,color:#0000ff
# ```
#
#
# ## MF02
# ```mermaid
# flowchart LR
#         A5[IN0150] -->|TRUE| C5{任一訊號為TRUE}
#         B5[UA0069] -->|TRUE| C5
#         D5[UA0125] -->|TRUE| C5
#         G5[IN0130] -->|TRUE| C5
#         H5[IN0143] -->|TRUE| C5
#         I5[IN0133] -->|TRUE| C5
#         J5[IN0132] -->|TRUE| C5
#         K5[DI0045] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C5
#         C5 -->|TRUE| E5[MF02 = TRUE]
#         C5 -->|FALSE| F5[MF02 維持 FALSE]
# ```

# %% [markdown]
# # SEQ006-G180
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[IN0150] -->|TRUE| C2{任一訊號為TRUE}
#         B2[UA0069] -->|TRUE| C2
#         D2[UA0125] -->|TRUE| C2
#         G2[IN0130] -->|TRUE| C2
#         H2[IN0143] -->|TRUE| C2
#         I2[IN0133] -->|TRUE| C2
#         K2[DI0045] -->|TRUE| C2
#         C2 -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#    subgraph MF03判斷
#         direction LR
#         A3[DI0033] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C3{任一訊號為TRUE}
#         B3[IX000] -->|TRUE| C3
#         C3 -->|TRUE| E3[MF03 = TRUE]
#         C3 -->|FALSE| F3[MF03 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     E3 --> C4
#     C4 -->|TRUE| E4[UA0255 = TRUE]
#     end
#
#     subgraph 警報復歸
#
#         E4[UA0255] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| B4[DO0040=1]
#     end
# ```

# %% [markdown]
# # SEQ007-FV1111
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[IN0150] -->|TRUE| C2{任一訊號為TRUE}
#         B2[NOT-DI0067] -->|TRUE| C2
#         D2[IN0130] -->|TRUE| C2
#         G2[IN0124] -->|TRUE| C2
#         C2 -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#    subgraph MF03判斷
#         direction LR
#         A3[IN0166] -->|TRUE| C3{任一訊號為TRUE}
#         B3[IX000] -->|TRUE| C3
#         C3 -->|TRUE| E3[MF03 = TRUE]
#         C3 -->|FALSE| F3[MF03 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     E3 --> C4
#     C4 -->|TRUE| E4[UA0256 = 1]
#     C4 -->|TRUE| E5[BL0002 = 1 啟動BLS演算]
#     end
#
#     subgraph 警報復歸
#         E4[UA0256] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| F4[DO0071=1]
#     end
# ```

# %% [markdown]
# # SEQ008-NV1102
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         M1[IN0109] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[UA0069] -->|TRUE| C2{任一訊號為TRUE}
#         B2[IX000] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[VI004 = TRUE]
#     C4 -->|FALSE| K5[VI004 維持 FALSE]
#     end
# ```
# ## ZO0067(A/M mode; 0=A / 1=M)常時為1,若不等於1 則發警報
# ```mermaid
#     flowchart LR
#         A3[IX0001] -->|TRUE| A4[ZO0067=1=M]
#         A4 -->B3[DB0067=0=M] -->|DB0067=0| B4[DI1004=1<br>UA0257=0]
#         B3 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT DB0067=1</font>"| D4[DI1004=0<br>UA0257=1]
# ```

# %% [markdown]
# # SEQ009-FV1122
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     M1[IX001] --> C4
#     C4 -->|TRUE| K4[UA0258 = TRUE]
#     C4 -->|TRUE| K5[BL003 = TRUE]
#     end
#
#     subgraph 警報復歸
#         K4 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| F4[DO0073 = TRUE]
#     end
# ```

# %% [markdown]
# # SEQ010-FV1301
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[IN0174] -->|TRUE| C2{任一訊號為TRUE}
#         B2[IX000] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#         E1 --> C4{任一MF為TRUE}
#         E2 --> C4
#         C4 -->|TRUE| K4[UA0259 = TRUE]
#         C4 -->|TRUE| K5[BL004 = TRUE]
#     end
#
#     subgraph 警報復歸
#         K4[UA0259] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| F4[DO0070=TRUE]
#     end
# ```

# %% [markdown]
# # SEQ011-FV4001
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[IN0175] -->|TRUE| C2{任一訊號為TRUE}
#         B2[IN0176] -->|TRUE| C2
#         D2[DI0036] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2
#         G2[IN0110] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[UA0260 = TRUE]
#     C4 -->|TRUE| K5[BL005 = TRUE]
#     end
#
#     subgraph 警報復歸
#         K4[UA0260] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| F4[DO0069=TRUE]
#     end
# ```

# %% [markdown]
# # SEQ012-E130
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[IN0111] -->|TRUE| C2{任一訊號為TRUE}
#         D2[DI0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2
#         G2[IN0174] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[UA0261 = TRUE]
#     end
#
#     subgraph 警報復歸
#         K4[UA0261] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| B4[DO0038=TRUE]
#     end
# ```

# %% [markdown]
# # SEQ013-E400
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[IN0110] -->|TRUE| C2{任一訊號為TRUE}
#         D2[DI0036] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2
#         G2[IN0175] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[UA0262 = TRUE]
#     end
#
#     subgraph 警報復歸
#         K4[UA0262] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| F4[DO0039=TRUE]
#     end
# ```
